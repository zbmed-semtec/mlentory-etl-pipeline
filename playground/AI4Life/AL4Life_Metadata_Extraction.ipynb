# %% [markdown]
# ## Exploration of AI4Life platfrom to extract metadata
#
# + Upon reviewing available resources, it appears that BioModelZoo does not maintain a centralized JSON index or API for accessing RDF YAML files.
#
# + These rdf.yaml files adhere to a standardized format defined by the bioimage.io community, facilitating consistent descriptions of bioimage models and resources. While the repository provides example files, it does not offer a centralized JSON index listing all available rdf.yaml files.​
#
# + To programmatically access and work with these files, you can utilize the `bioimageio.core` Python package. This package provides functionalities to load, validate, and interact with BioImage.IO resources.
#
# + Download Files Programmatically: While there's no centralized JSON index, one can programmatically access and download these files by scraping the website or using available tools.

# %% [markdown]
# ## Implementation

# %%
# !pip install bioimageio.core
# Out:
# Collecting bioimageio.core
#   Obtaining dependency information for bioimageio.core from https://files.pythonhosted.org/packages/32/33/10262047b6dc5dfea11571009135413f473201a42d077e7e57551107abf4/bioimageio_core-0.8.0-py3-none-any.whl.metadata
#   Downloading bioimageio_core-0.8.0-py3-none-any.whl.metadata (23 kB)
# Collecting bioimageio.spec==0.5.4.1 (from bioimageio.core)
#   Obtaining dependency information for bioimageio.spec==0.5.4.1 from https://files.pythonhosted.org/packages/c0/b5/0e199ece54e44e9183b117cad9676398bcdeb1c5b8e6554aa44e223dbb74/bioimageio.spec-0.5.4.1-py3-none-any.whl.metadata
#   Downloading bioimageio.spec-0.5.4.1-py3-none-any.whl.metadata (11 kB)
# Collecting h5py (from bioimageio.core)
#   Obtaining dependency information for h5py from https://files.pythonhosted.org/packages/25/61/d897952629cae131c19d4c41b2521e7dd6382f2d7177c87615c2e6dced1a/h5py-3.13.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading h5py-3.13.0-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Collecting imagecodecs (from bioimageio.core)
#   Obtaining dependency information for imagecodecs from https://files.pythonhosted.org/packages/b6/42/e73497e12c5e1f3a98dc0c07a8ac80ee3b728e03cb397475337540b02432/imagecodecs-2025.3.30-cp312-cp312-win_amd64.whl.metadata
#   Downloading imagecodecs-2025.3.30-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting imageio>=2.10 (from bioimageio.core)
#   Obtaining dependency information for imageio>=2.10 from https://files.pythonhosted.org/packages/cb/bd/b394387b598ed84d8d0fa90611a90bee0adc2021820ad5729f7ced74a8e2/imageio-2.37.0-py3-none-any.whl.metadata
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting loguru (from bioimageio.core)
#   Obtaining dependency information for loguru from https://files.pythonhosted.org/packages/0c/29/0348de65b8cc732daa3e33e67806420b2ae89bdce2b04af740289c5c6c8c/loguru-0.7.3-py3-none-any.whl.metadata
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting numpy (from bioimageio.core)
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/8b/09/4ffb4d6cfe7ca6707336187951992bd8a8b9142cf345d87ab858d2d7636a/numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata
#   Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Collecting pydantic-settings<3,>=2.5 (from bioimageio.core)
#   Obtaining dependency information for pydantic-settings<3,>=2.5 from https://files.pythonhosted.org/packages/b6/5f/d6d641b490fd3ec2c4c13b4244d68deea3a1b970a97be64f34fb5504ff72/pydantic_settings-2.9.1-py3-none-any.whl.metadata
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting pydantic<3,>=2.7.0 (from bioimageio.core)
#   Obtaining dependency information for pydantic<3,>=2.7.0 from https://files.pythonhosted.org/packages/b0/1d/407b29780a289868ed696d1616f4aad49d6388e5a77f567dcd2629dcd7b8/pydantic-2.11.3-py3-none-any.whl.metadata
#   Downloading pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
#      ---------------------------------------- 0.0/65.2 kB ? eta -:--:--
#      ------------------------------------- -- 61.4/65.2 kB ? eta -:--:--
#      ---------------------------------------- 65.2/65.2 kB 1.2 MB/s eta 0:00:00
# Collecting requests (from bioimageio.core)
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting ruyaml (from bioimageio.core)
#   Obtaining dependency information for ruyaml from https://files.pythonhosted.org/packages/1e/9a/16ca152a04b231c179c626de40af1d5d0bc2bc57bc875c397706016ddb2b/ruyaml-0.91.0-py3-none-any.whl.metadata
#   Downloading ruyaml-0.91.0-py3-none-any.whl.metadata (12 kB)
# Collecting tqdm (from bioimageio.core)
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB 1.5 MB/s eta 0:00:00
# Collecting typing-extensions (from bioimageio.core)
#   Obtaining dependency information for typing-extensions from https://files.pythonhosted.org/packages/8b/54/b1ae86c0973cc6f0210b53d508ca3641fb6d0c56823f288d108bc7ab3cc8/typing_extensions-4.13.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting xarray<2025.3.0,>=2023.01 (from bioimageio.core)
#   Obtaining dependency information for xarray<2025.3.0,>=2023.01 from https://files.pythonhosted.org/packages/05/79/4e19100342fe13d69fd6e77b343e2269924fec681258e2ea21b55576aad2/xarray-2025.1.2-py3-none-any.whl.metadata
#   Downloading xarray-2025.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting annotated-types<1,>=0.5.0 (from bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for annotated-types<1,>=0.5.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting email-validator (from bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for email-validator from https://files.pythonhosted.org/packages/d7/ee/bf0adb559ad3c786f12bcbc9296b3f5675f529199bef03e2df281fa1fadb/email_validator-2.2.0-py3-none-any.whl.metadata
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting markdown (from bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for markdown from https://files.pythonhosted.org/packages/51/3f/afe76f8e2246ffbc867440cbcf90525264df0e658f8a5ca1f872b3f6192a/markdown-3.8-py3-none-any.whl.metadata
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\solanki\appdata\roaming\python\python312\site-packages (from bioimageio.spec==0.5.4.1->bioimageio.core) (24.1)
# Collecting pooch<2,>=1.5 (from bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for pooch<2,>=1.5 from https://files.pythonhosted.org/packages/a8/87/77cc11c7a9ea9fd05503def69e3d18605852cd0d4b0d3b8f15bbeb3ef1d1/pooch-1.8.2-py3-none-any.whl.metadata
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting pydantic<3,>=2.7.0 (from bioimageio.core)
#   Obtaining dependency information for pydantic<3,>=2.7.0 from https://files.pythonhosted.org/packages/df/e4/ba44652d562cbf0bf320e0f3810206149c8a4e99cdbf66da82e97ab53a15/pydantic-2.9.2-py3-none-any.whl.metadata
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#      ---------------------------------------- 0.0/149.4 kB ? eta -:--:--
#      -------------------------------------- 149.4/149.4 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\users\solanki\appdata\roaming\python\python312\site-packages (from bioimageio.spec==0.5.4.1->bioimageio.core) (2.9.0.post0)
# Collecting rich (from bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/0d/9b/63f4c7ebc259242c89b3acafdb37b41d1185c07ff0011164674e9076b491/rich-14.0.0-py3-none-any.whl.metadata
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting tifffile>=2020.7.4 (from bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for tifffile>=2020.7.4 from https://files.pythonhosted.org/packages/6e/be/10d23cfd4078fbec6aba768a357eff9e70c0b6d2a07398425985c524ad2a/tifffile-2025.3.30-py3-none-any.whl.metadata
#   Downloading tifffile-2025.3.30-py3-none-any.whl.metadata (32 kB)
# Collecting zipp (from bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for zipp from https://files.pythonhosted.org/packages/b7/1a/7e4798e9339adc931158c9d69ecc34f5e6791489d469f5e50ec15e35f458/zipp-3.21.0-py3-none-any.whl.metadata
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pillow>=8.3.2 (from imageio>=2.10->bioimageio.core)
#   Obtaining dependency information for pillow>=8.3.2 from https://files.pythonhosted.org/packages/7c/18/24bff2ad716257fc03da964c5e8f05d9790a779a8895d6566e493ccf0189/pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<3,>=2.7.0->bioimageio.core)
#   Obtaining dependency information for pydantic-core==2.23.4 from https://files.pythonhosted.org/packages/88/8d/479293e4d39ab409747926eec4329de5b7129beaedc3786eca070605d07f/pydantic_core-2.23.4-cp312-none-win_amd64.whl.metadata
#   Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3,>=2.5->bioimageio.core)
#   Obtaining dependency information for python-dotenv>=0.21.0 from https://files.pythonhosted.org/packages/1e/18/98a99ad95133c6a6e2005fe89faedf294a748bd5dc803008059409ac9b1e/python_dotenv-1.1.0-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings<3,>=2.5->bioimageio.core)
#   Obtaining dependency information for typing-inspection>=0.4.0 from https://files.pythonhosted.org/packages/31/08/aa4fdfb71f7de5176385bd9e90852eaf6b5d622735020ad600f2bab54385/typing_inspection-0.4.0-py3-none-any.whl.metadata
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pandas>=2.1 (from xarray<2025.3.0,>=2023.01->bioimageio.core)
#   Obtaining dependency information for pandas>=2.1 from https://files.pythonhosted.org/packages/29/d4/1244ab8edf173a10fd601f7e13b9566c1b525c4f365d6bee918e68381889/pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\solanki\appdata\roaming\python\python312\site-packages (from loguru->bioimageio.core) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru->bioimageio.core)
#   Obtaining dependency information for win32-setctime>=1.0.0 from https://files.pythonhosted.org/packages/e1/07/c6fe3ad3e685340704d314d765b7912993bcb8dc198f0e7a89382d37974b/win32_setctime-1.2.0-py3-none-any.whl.metadata
#   Downloading win32_setctime-1.2.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests->bioimageio.core)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/21/5b/1b390b03b1d16c7e382b561c5329f83cc06623916aab983e8ab9239c7d5c/charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests->bioimageio.core)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->bioimageio.core)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/6b/11/cc635220681e93a0183390e26485430ca2c7b5f9d33b15c74c2861cb8091/urllib3-2.4.0-py3-none-any.whl.metadata
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->bioimageio.core)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/38/fc/bce832fd4fd99766c04d1ee0eead6b0ec6486fb100ae5e74c1d91292b982/certifi-2025.1.31-py3-none-any.whl.metadata
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting distro>=1.3.0 (from ruyaml->bioimageio.core)
#   Obtaining dependency information for distro>=1.3.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting setuptools>=39.0 (from ruyaml->bioimageio.core)
#   Obtaining dependency information for setuptools>=39.0 from https://files.pythonhosted.org/packages/cc/ea/d53f2f8897c46a36df085964d07761ea4c2d1f2cf92019693b6742b7aabb/setuptools-79.0.0-py3-none-any.whl.metadata
#   Downloading setuptools-79.0.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pytz>=2020.1 (from pandas>=2.1->xarray<2025.3.0,>=2023.01->bioimageio.core)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.1->xarray<2025.3.0,>=2023.01->bioimageio.core)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/5c/23/c7abc0ca0a1526a0774eca151daeb8de62ec457e77262b66b359c3c7679e/tzdata-2025.2-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\solanki\appdata\roaming\python\python312\site-packages (from pooch<2,>=1.5->bioimageio.spec==0.5.4.1->bioimageio.core) (4.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\solanki\appdata\roaming\python\python312\site-packages (from python-dateutil->bioimageio.spec==0.5.4.1->bioimageio.core) (1.16.0)
# Collecting dnspython>=2.0.0 (from email-validator->bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for dnspython>=2.0.0 from https://files.pythonhosted.org/packages/68/1b/e0a87d256e40e8c888847551b20a017a6b98139178505dc7ffb96f04e954/dnspython-2.7.0-py3-none-any.whl.metadata
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\solanki\appdata\roaming\python\python312\site-packages (from rich->bioimageio.spec==0.5.4.1->bioimageio.core) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->bioimageio.spec==0.5.4.1->bioimageio.core)
#   Obtaining dependency information for mdurl~=0.1 from https://files.pythonhosted.org/packages/b3/38/89ba8ad64ae25be8de66a6d463314cf1eb366222074cfda9ee839c56a4b4/mdurl-0.1.2-py3-none-any.whl.metadata
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading bioimageio_core-0.8.0-py3-none-any.whl (174 kB)
#    ---------------------------------------- 0.0/174.7 kB ? eta -:--:--
#    --------------------------------------- 174.7/174.7 kB 11.0 MB/s eta 0:00:00
# Downloading bioimageio.spec-0.5.4.1-py3-none-any.whl (210 kB)
#    ---------------------------------------- 0.0/210.3 kB ? eta -:--:--
#    --------------------------------------- 210.3/210.3 kB 12.5 MB/s eta 0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#    ---------------------------------------- 0.0/315.8 kB ? eta -:--:--
#    -------------------------------------- - 307.2/315.8 kB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 315.8/315.8 kB 6.5 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/12.6 MB 7.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/12.6 MB 8.7 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/12.6 MB 7.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/12.6 MB 7.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/12.6 MB 7.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.6 MB 6.9 MB/s eta 0:00:02
#    ------ --------------------------------- 2.2/12.6 MB 6.9 MB/s eta 0:00:02
#    ------- -------------------------------- 2.5/12.6 MB 6.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.8/12.6 MB 6.8 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.6 MB 6.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.6 MB 6.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.6 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 4.0/12.6 MB 6.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.3/12.6 MB 6.7 MB/s eta 0:00:02
#    -------------- ------------------------- 4.6/12.6 MB 6.6 MB/s eta 0:00:02
#    --------------- ------------------------ 4.9/12.6 MB 6.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.1/12.6 MB 6.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.4/12.6 MB 6.8 MB/s eta 0:00:02
#    ------------------ --------------------- 5.7/12.6 MB 6.6 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.6 MB 6.6 MB/s eta 0:00:01
#    ------------------- -------------------- 6.3/12.6 MB 6.6 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.6 MB 6.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.9/12.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.2/12.6 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.5/12.6 MB 6.6 MB/s eta 0:00:01
#    ------------------------ --------------- 7.8/12.6 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.6 MB 6.6 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.6 MB 6.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.8/12.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.1/12.6 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.6 MB 6.6 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 9.9/12.6 MB 6.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 6.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.8/12.6 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.6 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 11.4/12.6 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------- -- 11.7/12.6 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.6 MB 6.6 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.6 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 6.1 MB/s eta 0:00:00
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#    ---------------------------------------- 0.0/434.9 kB ? eta -:--:--
#    -------------------------------- ------ 358.4/434.9 kB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 434.9/434.9 kB 6.7 MB/s eta 0:00:00
# Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.9 MB 9.6 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/1.9 MB 8.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 7.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.4 MB/s eta 0:00:00
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#    ---------------------------------------- 44.4/44.4 kB ? eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.8 kB ? eta -:--:--
#    ---------------------------------------- 45.8/45.8 kB ? eta 0:00:00
# Downloading xarray-2025.1.2-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------- ---------------------------- 0.3/1.2 MB 7.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.7/1.2 MB 8.8 MB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 6.1 MB/s eta 0:00:00
# Downloading h5py-3.13.0-cp312-cp312-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.4/3.0 MB 8.1 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/3.0 MB 7.6 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/3.0 MB 7.3 MB/s eta 0:00:01
#    ------------------ --------------------- 1.4/3.0 MB 6.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.7/3.0 MB 7.1 MB/s eta 0:00:01
#    -------------------------- ------------- 2.0/3.0 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.3/3.0 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.6/3.0 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  2.9/3.0 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  2.9/3.0 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 6.1 MB/s eta 0:00:00
# Downloading imagecodecs-2025.3.30-cp312-cp312-win_amd64.whl (28.9 MB)
#    ---------------------------------------- 0.0/28.9 MB ? eta -:--:--
#     --------------------------------------- 0.6/28.9 MB 13.1 MB/s eta 0:00:03
#    - -------------------------------------- 1.0/28.9 MB 10.1 MB/s eta 0:00:03
#    - -------------------------------------- 1.3/28.9 MB 8.9 MB/s eta 0:00:04
#    -- ------------------------------------- 1.6/28.9 MB 7.8 MB/s eta 0:00:04
#    -- ------------------------------------- 1.8/28.9 MB 7.8 MB/s eta 0:00:04
#    --- ------------------------------------ 2.2/28.9 MB 7.4 MB/s eta 0:00:04
#    --- ------------------------------------ 2.6/28.9 MB 7.5 MB/s eta 0:00:04
#    --- ------------------------------------ 2.9/28.9 MB 7.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 3.2/28.9 MB 7.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 3.5/28.9 MB 7.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.8/28.9 MB 7.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 4.1/28.9 MB 7.1 MB/s eta 0:00:04
#    ------ --------------------------------- 4.4/28.9 MB 7.1 MB/s eta 0:00:04
#    ------ --------------------------------- 4.8/28.9 MB 6.9 MB/s eta 0:00:04
#    ------- -------------------------------- 5.1/28.9 MB 7.0 MB/s eta 0:00:04
#    ------- -------------------------------- 5.3/28.9 MB 6.9 MB/s eta 0:00:04
#    ------- -------------------------------- 5.6/28.9 MB 6.9 MB/s eta 0:00:04
#    -------- ------------------------------- 5.9/28.9 MB 6.9 MB/s eta 0:00:04
#    -------- ------------------------------- 6.2/28.9 MB 6.9 MB/s eta 0:00:04
#    --------- ------------------------------ 6.6/28.9 MB 6.9 MB/s eta 0:00:04
#    --------- ------------------------------ 6.9/28.9 MB 6.9 MB/s eta 0:00:04
#    --------- ------------------------------ 7.1/28.9 MB 6.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 7.4/28.9 MB 6.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 7.8/28.9 MB 6.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 8.1/28.9 MB 6.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 8.4/28.9 MB 6.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 8.7/28.9 MB 6.8 MB/s eta 0:00:03
#    ------------ --------------------------- 9.0/28.9 MB 6.8 MB/s eta 0:00:03
#    ------------ --------------------------- 9.3/28.9 MB 6.8 MB/s eta 0:00:03
#    ------------- -------------------------- 9.6/28.9 MB 6.7 MB/s eta 0:00:03
#    ------------- -------------------------- 9.9/28.9 MB 6.7 MB/s eta 0:00:03
#    -------------- ------------------------- 10.2/28.9 MB 6.8 MB/s eta 0:00:03
#    -------------- ------------------------- 10.5/28.9 MB 6.5 MB/s eta 0:00:03
#    --------------- ------------------------ 10.9/28.9 MB 6.5 MB/s eta 0:00:03
#    --------------- ------------------------ 11.2/28.9 MB 6.5 MB/s eta 0:00:03
#    --------------- ------------------------ 11.5/28.9 MB 6.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 11.8/28.9 MB 6.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 12.1/28.9 MB 6.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 12.5/28.9 MB 6.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 12.8/28.9 MB 6.5 MB/s eta 0:00:03
#    ------------------ --------------------- 13.1/28.9 MB 6.5 MB/s eta 0:00:03
#    ------------------ --------------------- 13.4/28.9 MB 6.5 MB/s eta 0:00:03
#    ------------------ --------------------- 13.7/28.9 MB 6.5 MB/s eta 0:00:03
#    ------------------- -------------------- 14.0/28.9 MB 6.5 MB/s eta 0:00:03
#    ------------------- -------------------- 14.3/28.9 MB 6.5 MB/s eta 0:00:03
#    -------------------- ------------------- 14.6/28.9 MB 6.5 MB/s eta 0:00:03
#    -------------------- ------------------- 14.9/28.9 MB 6.5 MB/s eta 0:00:03
#    --------------------- ------------------ 15.2/28.9 MB 6.5 MB/s eta 0:00:03
#    --------------------- ------------------ 15.5/28.9 MB 6.5 MB/s eta 0:00:03
#    --------------------- ------------------ 15.7/28.9 MB 6.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 16.0/28.9 MB 6.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 16.3/28.9 MB 6.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 16.6/28.9 MB 6.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 16.9/28.9 MB 6.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 17.2/28.9 MB 6.6 MB/s eta 0:00:02
#    ------------------------ --------------- 17.6/28.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------ --------------- 17.9/28.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------- -------------- 18.2/28.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------- -------------- 18.4/28.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------- -------------- 18.7/28.9 MB 6.5 MB/s eta 0:00:02
#    -------------------------- ------------- 19.0/28.9 MB 6.5 MB/s eta 0:00:02
#    -------------------------- ------------- 19.3/28.9 MB 6.5 MB/s eta 0:00:02
#    --------------------------- ------------ 19.6/28.9 MB 6.5 MB/s eta 0:00:02
#    --------------------------- ------------ 19.9/28.9 MB 6.5 MB/s eta 0:00:02
#    --------------------------- ------------ 20.2/28.9 MB 6.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 20.4/28.9 MB 6.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 20.7/28.9 MB 6.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 21.0/28.9 MB 6.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 21.3/28.9 MB 6.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 21.6/28.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------------ --------- 21.9/28.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------------ --------- 22.2/28.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------------- -------- 22.5/28.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------- -------- 22.8/28.9 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 23.1/28.9 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 23.4/28.9 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 23.8/28.9 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 24.1/28.9 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 24.4/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 24.7/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 25.0/28.9 MB 6.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.3/28.9 MB 6.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.6/28.9 MB 6.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.9/28.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 26.2/28.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 26.4/28.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 26.8/28.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 27.1/28.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 27.4/28.9 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 27.7/28.9 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 28.0/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  28.3/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  28.7/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  28.9/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  28.9/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  28.9/28.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 28.9/28.9 MB 5.8 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 3.4 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Downloading ruyaml-0.91.0-py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.9 kB ? eta -:--:--
#    ---------------------------------------- 108.9/108.9 kB 6.2 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 4.6 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    ---------------------------------------- 166.4/166.4 kB 5.0 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.8 kB ? eta -:--:--
#    ---------------------------------------- 102.8/102.8 kB 5.8 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB ? eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/11.5 MB 9.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/11.5 MB 9.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.5 MB 8.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/11.5 MB 7.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.5 MB 7.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/11.5 MB 6.9 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/11.5 MB 7.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.5/11.5 MB 6.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.7/11.5 MB 7.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.0/11.5 MB 6.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.3/11.5 MB 7.0 MB/s eta 0:00:02
#    ------------ --------------------------- 3.6/11.5 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.5 MB 6.8 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.5 MB 6.7 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/11.5 MB 6.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.8/11.5 MB 6.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.5 MB 6.7 MB/s eta 0:00:01
#    ------------------ --------------------- 5.4/11.5 MB 6.8 MB/s eta 0:00:01
#    ------------------- -------------------- 5.7/11.5 MB 6.8 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.5 MB 6.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 6.9/11.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 7.2/11.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.5/11.5 MB 6.7 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.2/11.5 MB 6.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.5 MB 6.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.8/11.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 9.1/11.5 MB 6.6 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.5 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.6/11.5 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------- -- 10.9/11.5 MB 6.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.2/11.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 6.2 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.7 MB 9.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.7 MB 7.7 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.7 MB 7.5 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.7 MB 7.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.7/2.7 MB 7.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.7 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.3/2.7 MB 7.0 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 6.6 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.6 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading setuptools-79.0.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ----------- ---------------------------- 0.3/1.3 MB 7.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.7/1.3 MB 7.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.3 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.3 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 6.1 MB/s eta 0:00:00
# Downloading tifffile-2025.3.30-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.8 kB ? eta -:--:--
#    ---------------------------------------- 226.8/226.8 kB 7.0 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.7 kB ? eta -:--:--
#    ---------------------------------------- 128.7/128.7 kB 3.8 MB/s eta 0:00:00
# Downloading win32_setctime-1.2.0-py3-none-any.whl (4.1 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.2 kB ? eta -:--:--
#    ---------------------------------------- 106.2/106.2 kB 6.0 MB/s eta 0:00:00
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#    ---------------------------------------- 0.0/243.2 kB ? eta -:--:--
#    ---------------------------------------- 243.2/243.2 kB 7.5 MB/s eta 0:00:00
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.6 kB ? eta -:--:--
#    ---------------------------------------  307.2/313.6 kB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 313.6/313.6 kB 6.5 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#    -------------------------- ------------- 337.9/509.2 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 509.2/509.2 kB 6.4 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#    -------------------------------------- - 337.9/347.8 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 347.8/347.8 kB 5.4 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, zipp, win32-setctime, urllib3, tzdata, typing-extensions, tqdm, setuptools, python-dotenv, pillow, numpy, mdurl, markdown, idna, dnspython, distro, charset-normalizer, certifi, annotated-types, typing-inspection, tifffile, ruyaml, requests, pydantic-core, pandas, markdown-it-py, loguru, imageio, imagecodecs, h5py, email-validator, xarray, rich, pydantic, pooch, pydantic-settings, bioimageio.spec, bioimageio.core
# Successfully installed annotated-types-0.7.0 bioimageio.core-0.8.0 bioimageio.spec-0.5.4.1 certifi-2025.1.31 charset-normalizer-3.4.1 distro-1.9.0 dnspython-2.7.0 email-validator-2.2.0 h5py-3.13.0 idna-3.10 imagecodecs-2025.3.30 imageio-2.37.0 loguru-0.7.3 markdown-3.8 markdown-it-py-3.0.0 mdurl-0.1.2 numpy-2.2.5 pandas-2.2.3 pillow-11.2.1 pooch-1.8.2 pydantic-2.9.2 pydantic-core-2.23.4 pydantic-settings-2.9.1 python-dotenv-1.1.0 pytz-2025.2 requests-2.32.3 rich-14.0.0 ruyaml-0.91.0 setuptools-79.0.0 tifffile-2025.3.30 tqdm-4.67.1 typing-extensions-4.13.2 typing-inspection-0.4.0 tzdata-2025.2 urllib3-2.4.0 win32-setctime-1.2.0 xarray-2025.1.2 zipp-3.21.0
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Enable pretty_validation_errors

# %%
from bioimageio.spec.pretty_validation_errors import (
    enable_pretty_validation_errors_in_ipynb,
)

enable_pretty_validation_errors_in_ipynb()

# %%
import bioimageio.core
from bioimageio.core import load_description

# %% [markdown]
# ## Load model from the BioImage Model Zoo

# %% [markdown]
# bioimage.io resources may be identified via their bioimage.io ID, e.g. "affable-shark" or the DOI of their Zenodo backup.
#
# Both of these options may be version specific ("affable-shark/1" or a version specific Zenodo backup DOI).
#
# Alternatively, any rdf.yaml source, single file or in a .zip, may be loaded by providing its local path or URL.

# %%
BMZ_MODEL_ID = ""  # "affable-shark"
BMZ_MODEL_DOI = ""  # "10.5281/zenodo.6287342"
BMZ_MODEL_URL = "https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/affable-shark/1.2/files/rdf.yaml"

# %%
from bioimageio.core import load_description

# Load the model description
# ------------------------------------------------------------------------------
if BMZ_MODEL_ID != "":
    model = load_description(BMZ_MODEL_ID)
    print(
        f"\nThe model '{model.name}' with ID '{BMZ_MODEL_ID}' has been correctly loaded."
    )
elif BMZ_MODEL_DOI != "":
    model = load_description(BMZ_MODEL_DOI)
    print(
        f"\nThe model '{model.name}' with DOI '{BMZ_MODEL_DOI}' has been correctly loaded."
    )
elif BMZ_MODEL_URL != "":
    model = load_description(BMZ_MODEL_URL)
    print(
        f"\nThe model '{model.name}' with URL '{BMZ_MODEL_URL}' has been correctly loaded."
    )
else:
    print("\nPlease specify a model ID, DOI or URL")

if "draft" in BMZ_MODEL_ID or "draft" in BMZ_MODEL_DOI or "draft" in BMZ_MODEL_URL:
    print(
        f"\nThis is the DRAFT version of '{model.name}'. \nDraft versions have not been reviewed by the Bioimage Model Zoo Team and may contain harmful code. Run with caution."
    )
# Out:
# The model 'NucleiSegmentationBoundaryModel' with URL 'https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/affable-shark/1.2/files/rdf.yaml' has been correctly loaded.

# %%
from bioimageio.core import test_model

test_summary = test_model(model)
test_summary.display()
# Out:
# 2025-04-23 09:57:43.985 | DEBUG    | bioimageio.core._resource_tests:_test_model_inference:593 - starting 'Reproduce test outputs from test inputs (pytorch_state_dict)'
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_reso │
# │ urce_tests.py:610 in _test_model_inference                                                       │
# │                                                                                                  │
# │   607 │   │   inputs = get_test_inputs(model)                                                    │
# │   608 │   │   expected = get_test_outputs(model)                                                 │
# │   609 │   │                                                                                      │
# │ ❱ 610 │   │   with create_prediction_pipeline(                                                   │
# │   611 │   │   │   bioimageio_model=model, devices=devices, weight_format=weight_format           │
# │   612 │   │   ) as prediction_pipeline:                                                          │
# │   613 │   │   │   results = prediction_pipeline.predict_sample_without_blocking(inputs)          │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_pred │
# │ iction_pipeline.py:371 in create_prediction_pipeline                                             │
# │                                                                                                  │
# │   368 │   │   │   f"deprecated create_prediction_pipeline kwargs: {set(deprecated_kwargs)}"      │
# │   369 │   │   )                                                                                  │
# │   370 │                                                                                          │
# │ ❱ 371 │   model_adapter = model_adapter or create_model_adapter(                                 │
# │   372 │   │   model_description=bioimageio_model,                                                │
# │   373 │   │   devices=devices,                                                                   │
# │   374 │   │   weight_format_priority_order=weights_format and (weights_format,),                 │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:169 in create                                                              │
# │                                                                                                  │
# │   166 │   │   assert errors                                                                      │
# │   167 │   │   if len(weight_format_priority_order) == 1:                                         │
# │   168 │   │   │   assert len(errors) == 1                                                        │
# │ ❱ 169 │   │   │   raise errors[0]                                                                │
# │   170 │   │                                                                                      │
# │   171 │   │   else:                                                                              │
# │   172 │   │   │   msg = (                                                                        │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:110 in create                                                              │
# │                                                                                                  │
# │   107 │   │   │   if wf == "pytorch_state_dict":                                                 │
# │   108 │   │   │   │   assert weights.pytorch_state_dict is not None                              │
# │   109 │   │   │   │   try:                                                                       │
# │ ❱ 110 │   │   │   │   │   from .pytorch_backend import PytorchModelAdapter                       │
# │   111 │   │   │   │   │                                                                          │
# │   112 │   │   │   │   │   return PytorchModelAdapter(                                            │
# │   113 │   │   │   │   │   │   model_description=model_description, devices=devices               │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\pytorch_backend.py:8 in <module>                                                             │
# │                                                                                                  │
# │     5 from pathlib import Path                                                                   │
# │     6 from typing import Any, List, Literal, Optional, Sequence, Union                           │
# │     7                                                                                            │
# │ ❱   8 import torch                                                                               │
# │     9 from loguru import logger                                                                  │
# │    10 from numpy.typing import NDArray                                                           │
# │    11 from torch import nn                                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'torch'
# 2025-04-23 09:57:44.231 | INFO     | bioimageio.core._resource_tests:_test_model_inference_parametrized:705 - Testing inference with 6 different inputs (B, N): {(1, 2), (2, 1), (1, 1), (2, 0), (2, 2), (1, 0)}
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_reso │
# │ urce_tests.py:763 in _test_model_inference_parametrized                                          │
# │                                                                                                  │
# │   760 │   try:                                                                                   │
# │   761 │   │   test_inputs = get_test_inputs(model)                                               │
# │   762 │   │                                                                                      │
# │ ❱ 763 │   │   with create_prediction_pipeline(                                                   │
# │   764 │   │   │   bioimageio_model=model, devices=devices, weight_format=weight_format           │
# │   765 │   │   ) as prediction_pipeline:                                                          │
# │   766 │   │   │   for n, batch_size, inputs, exptected_output_shape in generate_test_cases():    │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_pred │
# │ iction_pipeline.py:371 in create_prediction_pipeline                                             │
# │                                                                                                  │
# │   368 │   │   │   f"deprecated create_prediction_pipeline kwargs: {set(deprecated_kwargs)}"      │
# │   369 │   │   )                                                                                  │
# │   370 │                                                                                          │
# │ ❱ 371 │   model_adapter = model_adapter or create_model_adapter(                                 │
# │   372 │   │   model_description=bioimageio_model,                                                │
# │   373 │   │   devices=devices,                                                                   │
# │   374 │   │   weight_format_priority_order=weights_format and (weights_format,),                 │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:169 in create                                                              │
# │                                                                                                  │
# │   166 │   │   assert errors                                                                      │
# │   167 │   │   if len(weight_format_priority_order) == 1:                                         │
# │   168 │   │   │   assert len(errors) == 1                                                        │
# │ ❱ 169 │   │   │   raise errors[0]                                                                │
# │   170 │   │                                                                                      │
# │   171 │   │   else:                                                                              │
# │   172 │   │   │   msg = (                                                                        │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:110 in create                                                              │
# │                                                                                                  │
# │   107 │   │   │   if wf == "pytorch_state_dict":                                                 │
# │   108 │   │   │   │   assert weights.pytorch_state_dict is not None                              │
# │   109 │   │   │   │   try:                                                                       │
# │ ❱ 110 │   │   │   │   │   from .pytorch_backend import PytorchModelAdapter                       │
# │   111 │   │   │   │   │                                                                          │
# │   112 │   │   │   │   │   return PytorchModelAdapter(                                            │
# │   113 │   │   │   │   │   │   model_description=model_description, devices=devices               │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\pytorch_backend.py:8 in <module>                                                             │
# │                                                                                                  │
# │     5 from pathlib import Path                                                                   │
# │     6 from typing import Any, List, Literal, Optional, Sequence, Union                           │
# │     7                                                                                            │
# │ ❱   8 import torch                                                                               │
# │     9 from loguru import logger                                                                  │
# │    10 from numpy.typing import NDArray                                                           │
# │    11 from torch import nn                                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'torch'
# 2025-04-23 09:57:44.401 | DEBUG    | bioimageio.core._resource_tests:_test_model_inference:593 - starting 'Reproduce test outputs from test inputs (torchscript)'
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_reso │
# │ urce_tests.py:610 in _test_model_inference                                                       │
# │                                                                                                  │
# │   607 │   │   inputs = get_test_inputs(model)                                                    │
# │   608 │   │   expected = get_test_outputs(model)                                                 │
# │   609 │   │                                                                                      │
# │ ❱ 610 │   │   with create_prediction_pipeline(                                                   │
# │   611 │   │   │   bioimageio_model=model, devices=devices, weight_format=weight_format           │
# │   612 │   │   ) as prediction_pipeline:                                                          │
# │   613 │   │   │   results = prediction_pipeline.predict_sample_without_blocking(inputs)          │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_pred │
# │ iction_pipeline.py:371 in create_prediction_pipeline                                             │
# │                                                                                                  │
# │   368 │   │   │   f"deprecated create_prediction_pipeline kwargs: {set(deprecated_kwargs)}"      │
# │   369 │   │   )                                                                                  │
# │   370 │                                                                                          │
# │ ❱ 371 │   model_adapter = model_adapter or create_model_adapter(                                 │
# │   372 │   │   model_description=bioimageio_model,                                                │
# │   373 │   │   devices=devices,                                                                   │
# │   374 │   │   weight_format_priority_order=weights_format and (weights_format,),                 │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:169 in create                                                              │
# │                                                                                                  │
# │   166 │   │   assert errors                                                                      │
# │   167 │   │   if len(weight_format_priority_order) == 1:                                         │
# │   168 │   │   │   assert len(errors) == 1                                                        │
# │ ❱ 169 │   │   │   raise errors[0]                                                                │
# │   170 │   │                                                                                      │
# │   171 │   │   else:                                                                              │
# │   172 │   │   │   msg = (                                                                        │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:140 in create                                                              │
# │                                                                                                  │
# │   137 │   │   │   elif wf == "torchscript":                                                      │
# │   138 │   │   │   │   assert weights.torchscript is not None                                     │
# │   139 │   │   │   │   try:                                                                       │
# │ ❱ 140 │   │   │   │   │   from .torchscript_backend import TorchscriptModelAdapter               │
# │   141 │   │   │   │   │                                                                          │
# │   142 │   │   │   │   │   return TorchscriptModelAdapter(                                        │
# │   143 │   │   │   │   │   │   model_description=model_description, devices=devices               │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\torchscript_backend.py:6 in <module>                                                         │
# │                                                                                                  │
# │    3 import warnings                                                                             │
# │    4 from typing import Any, List, Optional, Sequence, Union                                     │
# │    5                                                                                             │
# │ ❱  6 import torch                                                                                │
# │    7 from numpy.typing import NDArray                                                            │
# │    8                                                                                             │
# │    9 from bioimageio.spec._internal.type_guards import is_list, is_tuple                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'torch'
# 2025-04-23 09:57:44.704 | INFO     | bioimageio.core._resource_tests:_test_model_inference_parametrized:705 - Testing inference with 6 different inputs (B, N): {(1, 2), (2, 1), (1, 1), (2, 0), (2, 2), (1, 0)}
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_reso │
# │ urce_tests.py:763 in _test_model_inference_parametrized                                          │
# │                                                                                                  │
# │   760 │   try:                                                                                   │
# │   761 │   │   test_inputs = get_test_inputs(model)                                               │
# │   762 │   │                                                                                      │
# │ ❱ 763 │   │   with create_prediction_pipeline(                                                   │
# │   764 │   │   │   bioimageio_model=model, devices=devices, weight_format=weight_format           │
# │   765 │   │   ) as prediction_pipeline:                                                          │
# │   766 │   │   │   for n, batch_size, inputs, exptected_output_shape in generate_test_cases():    │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\_pred │
# │ iction_pipeline.py:371 in create_prediction_pipeline                                             │
# │                                                                                                  │
# │   368 │   │   │   f"deprecated create_prediction_pipeline kwargs: {set(deprecated_kwargs)}"      │
# │   369 │   │   )                                                                                  │
# │   370 │                                                                                          │
# │ ❱ 371 │   model_adapter = model_adapter or create_model_adapter(                                 │
# │   372 │   │   model_description=bioimageio_model,                                                │
# │   373 │   │   devices=devices,                                                                   │
# │   374 │   │   weight_format_priority_order=weights_format and (weights_format,),                 │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:169 in create                                                              │
# │                                                                                                  │
# │   166 │   │   assert errors                                                                      │
# │   167 │   │   if len(weight_format_priority_order) == 1:                                         │
# │   168 │   │   │   assert len(errors) == 1                                                        │
# │ ❱ 169 │   │   │   raise errors[0]                                                                │
# │   170 │   │                                                                                      │
# │   171 │   │   else:                                                                              │
# │   172 │   │   │   msg = (                                                                        │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\_model_adapter.py:140 in create                                                              │
# │                                                                                                  │
# │   137 │   │   │   elif wf == "torchscript":                                                      │
# │   138 │   │   │   │   assert weights.torchscript is not None                                     │
# │   139 │   │   │   │   try:                                                                       │
# │ ❱ 140 │   │   │   │   │   from .torchscript_backend import TorchscriptModelAdapter               │
# │   141 │   │   │   │   │                                                                          │
# │   142 │   │   │   │   │   return TorchscriptModelAdapter(                                        │
# │   143 │   │   │   │   │   │   model_description=model_description, devices=devices               │
# │                                                                                                  │
# │ C:\Users\Solanki\AppData\Local\Programs\Python\Python311\Lib\site-packages\bioimageio\core\backe │
# │ nds\torchscript_backend.py:6 in <module>                                                         │
# │                                                                                                  │
# │    3 import warnings                                                                             │
# │    4 from typing import Any, List, Optional, Sequence, Union                                     │
# │    5                                                                                             │
# │ ❱  6 import torch                                                                                │
# │    7 from numpy.typing import NDArray                                                            │
# │    8                                                                                             │
# │    9 from bioimageio.spec._internal.type_guards import is_list, is_tuple                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'torch'
# <table>
#   <tr>
#     <th>❌</th>
#     <th>bioimageio format validation</th>
#   </tr>
#   <tr>
#     <td>status</td>
#     <td>failed</td>
#   </tr>
#   <tr>
#     <td>source</td>
#     <td>https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/affable-shark/1.2/files/rdf.yaml</td>
#   </tr>
#   <tr>
#     <td>id</td>
#     <td>10.5281/zenodo.5764892/6647674</td>
#   </tr>
#   <tr>
#     <td>format version</td>
#     <td>model 0.5.4</td>
#   </tr>
#   <tr>
#     <td>bioimageio.spec</td>
#     <td>0.5.4.1</td>
#   </tr>
#   <tr>
#     <td>bioimageio.core</td>
#     <td>0.8.0</td>
#   </tr>
# </table>
# <table>
#   <tr>
#     <th></th>
#     <th>Location</th>
#     <th>Details</th>
#   </tr>
#   <tr>
#     <td>✔️</td>
#     <td></td>
#     <td>Successfully created `ModelDescr` object.</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:perform_io_checks`</td>
#     <td>True</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:root`</td>
#     <td>https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/affable-shark/1.2/files</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.zero_mean_unit_variance.ijm`</td>
#     <td>767f2c3a50e36365c30b9e46e57fcf82e606d337e8a48d4a2440dc512813d186</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.test_input_0.npy`</td>
#     <td>c29bd6e16e3f7856217b407ba948222b1c2a0da41922a0f79297e25588614fe2</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.sample_input_0.tif`</td>
#     <td>a24b3c708b6ca6825494eb7c5a4d221335fb3eef5eb9d03f4108907cdaad2bf9</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.test_output_0.npy`</td>
#     <td>510181f38930e59e4fd8ecc03d6ea7c980eb6609759655f2d4a41fe36108d5f5</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.sample_output_0.tif`</td>
#     <td>e8f99aabe8405427f515eba23a49f58ba50302f57d1fdfd07026e1984f836c5e</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.unet.py`</td>
#     <td>7f5b15948e8e2c91f78dcff34fbf30af517073e91ba487f3edb982b948d099b3</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.weights.pt`</td>
#     <td>608f52cd7f5119f7a7b8272395b0c169714e8be34536eaf159820f72a1d6a5b7</td>
#   </tr>
#   <tr>
#     <td>🔍</td>
#     <td>`context:known_files.weights-torchscript.pt`</td>
#     <td>8410950508655a300793b389c815dc30b1334062fc1dadb1e15e55a93cbb99a0</td>
#   </tr>
#   <tr>
#     <td>✔️</td>
#     <td></td>
#     <td>bioimageio.spec format validation model 0.5.4</td>
#   </tr>
#   <tr>
#     <td>✔️</td>
#     <td><code>type</code></td>
#     <td>Has expected resource type</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td>Reproduce test outputs from test inputs (pytorch_state_dict)</td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>recommended conda env for:
# Reproduce test outputs from test inputs (pytorch_state_dict)
# <pre lang="yaml">%YAML 1.2
# ---
# channels:
#   - pytorch
#   - conda-forge
#   - nodefaults
# dependencies:
#   - conda-forge::bioimageio.core
#   - mkl ==2024.0.0
#   - numpy <2
#   - pip
#   - pytorch==1.13.0
#   - setuptools <70.0.0
#   - torchaudio==0.13.0
#   - torchvision==0.14.0
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>conda compare (Reproduce test outputs from test inputs (pytorch_state_dict)):
# <pre>'conda' is not recognized as an internal or external command,
# operable program or batch file.
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>No module named 'torch'</pre></td>
#   </tr>
#   <tr>
#     <td></td>
#     <td></td>
#     <td>See <a href="traceback-1">Traceback 1</a>.</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td>Run pytorch_state_dict inference for parametrized inputs</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>No module named 'torch'</pre></td>
#   </tr>
#   <tr>
#     <td></td>
#     <td></td>
#     <td>See <a href="traceback-2">Traceback 2</a>.</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.torchscript</code></td>
#     <td>Reproduce test outputs from test inputs (torchscript)</td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.torchscript</code></td>
#     <td><pre>recommended conda env for:
# Reproduce test outputs from test inputs (torchscript)
# <pre lang="yaml">%YAML 1.2
# ---
# channels:
#   - pytorch
#   - conda-forge
#   - nodefaults
# dependencies:
#   - conda-forge::bioimageio.core
#   - mkl ==2024.0.0
#   - numpy <2
#   - pip
#   - pytorch==1.13.0
#   - setuptools <70.0.0
#   - torchaudio==0.13.0
#   - torchvision==0.14.0
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.torchscript</code></td>
#     <td><pre>conda compare (Reproduce test outputs from test inputs (torchscript)):
# <pre>'conda' is not recognized as an internal or external command,
# operable program or batch file.
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.torchscript</code></td>
#     <td><pre>No module named 'torch'</pre></td>
#   </tr>
#   <tr>
#     <td></td>
#     <td></td>
#     <td>See <a href="traceback-3">Traceback 3</a>.</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.torchscript</code></td>
#     <td>Run torchscript inference for parametrized inputs</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.torchscript</code></td>
#     <td><pre>No module named 'torch'</pre></td>
#   </tr>
#   <tr>
#     <td></td>
#     <td></td>
#     <td>See <a href="left-out-details">Left out details</a>.</td>
#   </tr>
#   <tr>
#     <td>✔️</td>
#     <td><code>type</code></td>
#     <td>Has expected resource type</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td>Reproduce test outputs from test inputs (pytorch_state_dict)</td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>recommended conda env for:
# Reproduce test outputs from test inputs (pytorch_state_dict)
# <pre lang="yaml">%YAML 1.2
# ---
# channels:
#   - pytorch
#   - conda-forge
#   - nodefaults
# dependencies:
#   - conda-forge::bioimageio.core
#   - mkl ==2024.0.0
#   - numpy <2
#   - pip
#   - pytorch==1.13.0
#   - setuptools <70.0.0
#   - torchaudio==0.13.0
#   - torchvision==0.14.0
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>conda compare (Reproduce test outputs from test inputs (pytorch_state_dict)):
# <pre>'conda' is not recognized as an internal or external command,
# operable program or batch file.
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>No module named 'torch'</pre></td>
#   </tr>
#   <tr>
#     <td></td>
#     <td></td>
#     <td>See <a href="traceback-1">Traceback 1</a>.</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td>Run pytorch_state_dict inference for parametrized inputs</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.pytorch_state_dict</code></td>
#     <td><pre>No module named 'torch'</pre></td>
#   </tr>
#   <tr>
#     <td></td>
#     <td></td>
#     <td>See <a href="traceback-2">Traceback 2</a>.</td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights.torchscript</code></td>
#     <td>Reproduce test outputs from test inputs (torchscript)</td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.torchscript</code></td>
#     <td><pre>recommended conda env for:
# Reproduce test outputs from test inputs (torchscript)
# <pre lang="yaml">%YAML 1.2
# ---
# channels:
#   - pytorch
#   - conda-forge
#   - nodefaults
# dependencies:
#   - conda-forge::bioimageio.core
#   - mkl ==2024.0.0
#   - numpy <2
#   - pip
#   - pytorch==1.13.0
#   - setuptools <70.0.0
#   - torchaudio==0.13.0
#   - torchvision==0.14.0
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>🐍</td>
#     <td><code>weights.torchscript</code></td>
#     <td><pre>conda compare (Reproduce test outputs from test inputs (torchscript)):
# <pre>'conda' is not recognized as an internal or external command,
# operable program or batch file.
# </pre></pre></td>
#   </tr>
#   <tr>
#     <td>❌</td>
#     <td><code>weights

# %%
from pathlib import Path
import yaml

output_folder = Path("output")
output_folder.mkdir(exist_ok=True)

print(f"Folder '{output_folder}' created (or already exists)")

# # 2. Define the full path for the new YAML file
# yaml_file_path = output_folder / "my_data.yaml"
# Out:
# Folder 'output' created (or already exists)

# %% [markdown]
# ### Inspect the model metadata

# %%
from bioimageio.core  import load_description

# URL or RDF (Resource Description File) of a model
model_url = "https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/affable-shark/1.2/files/rdf.yaml"  # example model

# Load the resource description
rdf = load_description(model_url)
# pprint(rdf)


# Print some metadata
print('____________________________________________________________________________________')
print("Model Name:", rdf.name)
print("Description:", rdf.description)
print("Inputs:", rdf.inputs)
print("Outputs:", rdf.outputs)
print('_________________________________________________________________________________________________________________________________')
# Out:
# ____________________________________________________________________________________
# Model Name: NucleiSegmentationBoundaryModel
# Description: Nucleus segmentation for fluorescence microscopy
# Inputs: [InputTensorDescr(id='input0', description='', axes=[BatchAxis(id='batch', description='', type='batch', size=None), ChannelAxis(id='channel', description='', type='channel', channel_names=['channel0']), SpaceInputAxis(size=ParameterizedSize(min=64, step=16), id='y', description='', type='space', unit=None, scale=1.0, concatenable=False), SpaceInputAxis(size=ParameterizedSize(min=64, step=16), id='x', description='', type='space', unit=None, scale=1.0, concatenable=False)], test_tensor=FileDescr(source=RelativePath('test_input_0.npy'), sha256='c29bd6e16e3f7856217b407ba948222b1c2a0da41922a0f79297e25588614fe2'), sample_tensor=FileDescr(source=RelativePath('sample_input_0.tif'), sha256='a24b3c708b6ca6825494eb7c5a4d221335fb3eef5eb9d03f4108907cdaad2bf9'), data=IntervalOrRatioDataDescr(type='float32', range=(None, None), unit='arbitrary unit', scale=1.0, offset=None), optional=False, preprocessing=[EnsureDtypeDescr(id='ensure_dtype', kwargs=EnsureDtypeKwargs(dtype='float32')), ZeroMeanUnitVarianceDescr(id='zero_mean_unit_variance', kwargs=ZeroMeanUnitVarianceKwargs(axes=['channel', 'y', 'x'], eps=1e-06)), EnsureDtypeDescr(id='ensure_dtype', kwargs=EnsureDtypeKwargs(dtype='float32'))])]
# Outputs: [OutputTensorDescr(id='output0', description='', axes=[BatchAxis(id='batch', description='', type='batch', size=None), ChannelAxis(id='channel', description='', type='channel', channel_names=['channel0', 'channel1']), SpaceOutputAxisWithHalo(halo=16, size=SizeReference(tensor_id='input0', axis_id='y', offset=0), id='y', description='', type='space', unit=None, scale=1.0), SpaceOutputAxisWithHalo(halo=16, size=SizeReference(tensor_id='input0', axis_id='x', offset=0), id='x', description='', type='space', unit=None, scale=1.0)], test_tensor=FileDescr(source=RelativePath('test_output_0.npy'), sha256='510181f38930e59e4fd8ecc03d6ea7c980eb6609759655f2d4a41fe36108d5f5'), sample_tensor=FileDescr(source=RelativePath('sample_output_0.tif'), sha256='e8f99aabe8405427f515eba23a49f58ba50302f57d1fdfd07026e1984f836c5e'), data=IntervalOrRatioDataDescr(type='float32', range=(None, None), unit='arbitrary unit', scale=1.0, offset=None), postprocessing=[EnsureDtypeDescr(id='ensure_dtype', kwargs=EnsureDtypeKwargs(dtype='float32'))])]
# _________________________________________________________________________________________________________________________________

# %%
from bioimageio.core import load_description
from bioimageio.core import load_model_description
import random

# List of known model URLs or paths to their rdf.yaml files
model_urls = [
   "https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/affable-shark/1.2/files/rdf.yaml",
   "https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/chatty-frog/1/files/rdf.yaml",
"https://uk1s3.embassy.ebi.ac.uk/public-datasets/bioimage.io/hiding-tiger/1.1/files/rdf.yaml"
    # Add more model URLs as needed
]
#File will be automatically downloaded to 'bioimageio\Cache' folder.

# Select 3 random models
random_models = random.sample(model_urls, 3)

# Load and validate each model's rdf.yaml

for url in random_models:
    rdf = load_description(url)
    rdf_model = load_model_description(url)
    print('_________________________________________________________________________________________________________________________________')
    print("Model Name:", rdf.name)
    print("Model id:", rdf_model.id)
    print("Authors:", rdf.authors)
    print("Cite:", rdf.cite)
    print("Config:", rdf.config)
    print("Description:", rdf.description)
    print("Inputs:", rdf.inputs)
    print("Outputs:", rdf.outputs)
    print("Licence:", rdf.license)
    print("Links:", rdf.links)
    print('_________________________________________________________________________________________________________________________________')
# Out:
# _________________________________________________________________________________________________________________________________
# Model Name: NucleiSegmentationBoundaryModel
# Model id: 10.5281/zenodo.5764892/6647674
# Authors: [Author(affiliation='EMBL Heidelberg', email=None, orcid=None, name='Constantin Pape', github_user='constantinpape')]
# Cite: [CiteEntry(text='training library', doi='10.5281/zenodo.5108853', url=None), CiteEntry(text='architecture', doi='10.1007/978-3-319-24574-4_28', url=None), CiteEntry(text='segmentation algorithm', doi='10.1038/nmeth.4151', url=None), CiteEntry(text='data', doi=None, url='https://www.nature.com/articles/s41592-019-0612-7')]
# Config: bioimageio=BioimageioConfig(reproducibility_tolerance=(), nickname='affable-shark', nickname_icon='🦈', thumbnails={'cover.png': 'cover.thumbnail.png'}) _conceptdoi='10.5281/zenodo.5764892' deepimagej={'allow_tiling': True, 'model_keys': None, 'prediction': {'postprocess': [{'spec': None}], 'preprocess': [{'kwargs': 'zero_mean_unit_variance.ijm', 'spec': 'ij.IJ::runMacroFile'}]}, 'pyramidal_model': False, 'test_information': {'inputs': [{'name': 'sample_input_0.tif', 'pixel_size': {'x': 1, 'y': 1, 'z': 1}, 'size': '256 x 256 x 1 x 1'}], 'memory_peak': None, 'outputs': [{'name': 'sample_output_0.tif', 'size': '256 x 256 x 1 x 2', 'type': 'image'}], 'runtime': None}}
# Description: Nucleus segmentation for fluorescence microscopy
# Inputs: [InputTensorDescr(id='input0', description='', axes=[BatchAxis(id='batch', description='', type='batch', size=None), ChannelAxis(id='channel', description='', type='channel', channel_names=['channel0']), SpaceInputAxis(size=ParameterizedSize(min=64, step=16), id='y', description='', type='space', unit=None, scale=1.0, concatenable=False), SpaceInputAxis(size=ParameterizedSize(min=64, step=16), id='x', description='', type='space', unit=None, scale=1.0, concatenable=False)], test_tensor=FileDescr(source=RelativePath('test_input_0.npy'), sha256='c29bd6e16e3f7856217b407ba948222b1c2a0da41922a0f79297e25588614fe2'), sample_tensor=FileDescr(source=RelativePath('sample_input_0.tif'), sha256='a24b3c708b6ca6825494eb7c5a4d221335fb3eef5eb9d03f4108907cdaad2bf9'), data=IntervalOrRatioDataDescr(type='float32', range=(None, None), unit='arbitrary unit', scale=1.0, offset=None), optional=False, preprocessing=[EnsureDtypeDescr(id='ensure_dtype', kwargs=EnsureDtypeKwargs(dtype='float32')), ZeroMeanUnitVarianceDescr(id='zero_mean_unit_variance', kwargs=ZeroMeanUnitVarianceKwargs(axes=['channel', 'y', 'x'], eps=1e-06)), EnsureDtypeDescr(id='ensure_dtype', kwargs=EnsureDtypeKwargs(dtype='float32'))])]
# Outputs: [OutputTensorDescr(id='output0', description='', axes=[BatchAxis(id='batch', description='', type='batch', size=None), ChannelAxis(id='channel', description='', type='channel', channel_names=['channel0', 'channel1']), SpaceOutputAxisWithHalo(halo=16, size=SizeReference(tensor_id='input0', axis_id='y', offset=0), id='y', description='', type='space', unit=None, scale=1.0), SpaceOutputAxisWithHalo(halo=16, size=SizeReference(tensor_id='input0', axis_id='x', offset=0), id='x', description='', type='space', unit=None, scale=1.0)], test_tensor=FileDescr(source=RelativePath('test_output_0.npy'), sha256='510181f38930e59e4fd8ecc03d6ea7c980eb6609759655f2d4a41fe36108d5f5'), sample_tensor=FileDescr(source=RelativePath('sample_output_0.tif'), sha256='e8f99aabe8405427f515eba23a49f58ba50302f57d1fdfd07026e1984f836c5e'), data=IntervalOrRatioDataDescr(type='float32', range=(None, None), unit='arbitrary unit', scale=1.0, offset=None), postprocessing=[EnsureDtypeDescr(id='ensure_dtype', kwargs=EnsureDtypeKwargs(dtype='float32'))])]
# Licence: CC-BY-4.0
# Links: ['ilastik/stardist_dsb_training_data', 'ilastik/ilastik', 'deepimagej/deepimagej', 'imjoy/BioImageIO-Packager']
# _________________________________________________________________________________________________________________________________
# 2025-04-23 10:50:20.423 | Level 30 | bioimageio.spec._internal.field_warning:wrapper:78 - Custom dependencies (conda:environment.yaml) specified. Avoid this whenever possible to allow execution in a wider range of software environments.
# 2025-04-23 10:50:23.090 | Level 30 | bioimageio.spec._internal.field_warning:wrapper:78 - Custom dependencies (conda:environment.yaml) specified. Avoid this whenever possible to allow execution in a wider range of software environments.
# _________________________________________________________________________________________________________________________________
# Model Name: StarDist H&E Nuclei Segmentation
# Model id: 10.5281/zenodo.6338614/6338615
# Authors: [Author(affiliation=None, email=None, orcid=None, name='Uwe Schmidt', github_user='uschmidt83'), Author(affiliation=None, email=None, orcid=None, name='Martin Weigert', github_user='maweigert')]
# Cite: [CiteEntry(text='Cell Detection with Star-Convex Polygons', doi='10.1007/978-3-030-00934-2_30', url=None), CiteEntry(text='Star-convex Polyhedra for 3D Object Detection and Segmentation in Microscopy', doi='10.1109/WACV45572.2020.9093435', url=None)]
# Config: {'bioimageio': {'nickname': 'chatty-frog', 'nickname_icon': '🐸', 'thumbnails': {'example_histo.jpg': 'example_histo.thumbnail.png', 'stardist_logo.jpg': 'stardist_logo.thumbnail.png'}}, 'deepimagej': {'allow_tiling': True, 'model_keys': None, 'prediction': {'postprocess': [{'spec': None}], 'preprocess': [{'kwargs': 'per_sample_scale_range.ijm', 'spec': 'ij.IJ::runMacroFile'}]}, 'pyramidal_model': False, 'test_information': {'inputs': [{'name': 'test_input.npy', 'pixel_size': {'x': 1, 'y': 1, 'z': 1}, 'size': '512 x 304 x 1 x 3'}], 'memory_peak': None, 'outputs': [{'name': 'test_output.npy', 'size': '512 x 304 x 1 x 33', 'type': 'image'}], 'runtime': None}}, 'stardist': {'config': {'axes': 'YXC', 'backbone': 'unet', 'grid': [2, 2], 'n_channel_in': 3, 'n_channel_out': 33, 'n_classes': None, 'n_dim': 2, 'n_rays': 32, 'net_conv_after_unet': 128, 'net_input_shape': [None, None, 3], 'net_mask_shape': [None, None, 1], 'train_background_reg': 0.0001, 'train_batch_size': 8, 'train_checkpoint': 'weights_best.h5', 'train_checkpoint_epoch': 'weights_now.h5', 'train_checkpoint_last': 'weights_last.h5', 'train_class_weights': [1, 1], 'train_completion_crop': 32, 'train_dist_loss': 'mae', 'train_epochs': 200, 'train_foreground_only': 0.9, 'train_learning_rate': 0.0003, 'train_loss_weights': [1, 0.1], 'train_n_val_patches': 3, 'train_patch_size': [512, 512], 'train_reduce_lr': {'factor': 0.5, 'min_delta': 0, 'patience': 50}, 'train_sample_cache': True, 'train_shape_completion': False, 'train_steps_per_epoch': 200, 'train_tensorboard': True, 'unet_activation': 'relu', 'unet_batch_norm': False, 'unet_dropout': 0, 'unet_kernel_size': [3, 3], 'unet_last_activation': 'relu', 'unet_n_conv_per_depth': 2, 'unet_n_depth': 3, 'unet_n_filter_base': 32, 'unet_pool': [2, 2], 'unet_prefix': '', 'use_gpu': False}, 'postprocessing_macro': 'stardist_postprocessing.ijm', 'python_version': '0.7.3', 'thresholds': {'nms': 0.3, 'prob': 0.6924782541382084}, 'weights': 'stardist_weights.h5'}}
# Description: StarDist - Object Detection with Star-convex Shapes
# Inputs: [InputTensorDescr(name='input', description='', axes='byxc', data_range=(-inf, inf), data_type='float32', shape=ParameterizedInputShape(min=[1, 208, 208, 3], step=[0, 16, 16, 0]), preprocessing=[ScaleRangeDescr(name='scale_range', kwargs=ScaleRangeKwargs(mode='per_sample', axes='yxc', min_percentile=1, max_percentile=99.8, eps=1e-06, reference_tensor=None))])]
# Outputs: [OutputTensorDescr(name='output', description='', axes='byxc', data_range=(-inf, inf), data_type='float32', shape=ImplicitOutputShape(reference_tensor='input', scale=[1.0, 1.0, 1.0, 0.0], offset=[0, 0, 0, 16.5]), halo=[0, 96, 96, 0], postprocessing=[])]
# Licence: BSD-3-Clause
# Links: ['deepimagej/deepimagej', 'imjoy/BioImageIO-Packager', 'ilastik/tnbc', 'bioimageio/stardist', 'bioimageio/qupath']
# _________________________________________________________________________________________________________________________________
# _________________________________________________________________________________________________________________________________
# Model Name: LiveCellSegmentationBoundaryModel
# Model id: 10.5281/zenodo.5869899/6647688
# Authors: [Author(affiliation='EMBL Heidelberg', email=None, orcid=None, name='Constantin Pape', github_user=None)]
# Cite: [CiteEntry(text='training library', doi=None, url='https://doi.org/10.5281/zenodo.5108853'), CiteEntry(text='architecture', doi=None, url='https://doi.org/10.1007/978-3-319-24574-4_28'), CiteEntry(text='segmentation algorithm', doi=None, url='https://doi.org/10.1038/nmeth.4151'), CiteEntry(text='data', doi=None, url='https://www.nature.com/articles/s41592-021-01249-6')]
# Config: {'_conceptdoi': '10.5281/zenodo.5869899', 'bioimageio': {'nickname': 'hiding-tiger', 'nickname_icon': '🐅', 'thumbnails': {'cover.png': 'cover.thumbnail.png'}}, 'deepimagej': {'allow_tiling': True, 'model_keys': None, 'prediction': {'postprocess': [{'spec': None}], 'preprocess': [{'kwargs': 'zero_mean_unit_variance.ijm', 'spec': 'ij.IJ::runMacroFile'}]}, 'pyramidal_model': False, 'test_information': {'inputs': [{'name': 'sample_input_0.tif', 'pixel_size': {'x': 1, 'y': 1, 'z': 1}, 'size': '512 x 512 x 1 x 1'}], 'memory_peak': None, 'outputs': [{'name': 'sample_output_0.tif', 'size': '512 x 512 x 1 x 2', 'type': 'image'}], 'runtime': None}}}
# Description: Cell segmentation for phase-contrast microscopy.
# Inputs: [InputTensorDescr(name='input0', description='', axes='bcyx', data_range=None, data_type='float32', shape=ParameterizedInputShape(min=[1, 1, 32, 32], step=[0, 0, 16, 16]), preprocessing=[ZeroMeanUnitVarianceDescr(name='zero_mean_unit_variance', kwargs=ZeroMeanUnitVarianceKwargs(mode='per_sample', axes='cyx', mean=None, std=None, eps=1e-06))])]
# Outputs: [OutputTensorDescr(name='output0', description='', axes='bcyx', data_range=(-inf, inf), data_type='float32', shape=ImplicitOutputShape(reference_tensor='input0', scale=[1.0, 2.0, 1.0, 1.0], offset=[0, 0, 0, 0]), halo=[0, 0, 8, 8], postprocessing=[])]
# Licence: CC-BY-4.0
# Links: ['ilastik/livecell_dataset', 'ilastik/ilastik', 'deepimagej/deepimagej', 'imjoy/BioImageIO-Packager']
# _________________________________________________________________________________________________________________________________

# %%
# import yaml
# from rdflib import Graph, Namespace, URIRef, Literal
# from rdflib.namespace import RDF, RDFS

# # Step 1: Load RDF YAML file
# with open("model_rdf.yaml", "r") as f:
#     rdf_yaml = yaml.safe_load(f)

# # Step 2: Create RDF Graph
# g = Graph()

# # Define custom namespace (optional - replace with actual if known)
# BIOIMAGE = Namespace("https://bioimage.io/")

# # Example: Convert some fields to RDF triples (you'll need to adapt this to your RDF spec)
# model_uri = URIRef(rdf_yaml.get("id", "https://bioimage.io/example-model"))

# g.add((model_uri, RDF.type, BIOIMAGE.Model))
# g.add((model_uri, RDFS.label, Literal(rdf_yaml.get("name", "Unknown model"))))

# # Add authors (if available)
# authors = rdf_yaml.get("authors", [])
# for author in authors:
#     g.add((model_uri, BIOIMAGE.author, Literal(author.get("name", "Unknown Author"))))

# # Add more fields as needed...

# # Step 3: Serialize to Turtle format
# g.serialize(destination="model.ttl", format="turtle")

# print("Conversion complete! Turtle file saved as 'model.ttl'")
